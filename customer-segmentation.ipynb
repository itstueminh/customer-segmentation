# %% [markdown]
# Customer segmentation is the process of dividing customers into groups based on common charateristics so companies can market to each group effectively and appropriately

# %% [markdown]
# # Import necessarcy libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data exploration
